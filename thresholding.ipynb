# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./bottles.jpg',0)

# %%
plt.imshow(img,cmap='gray')

# %%
## All or nothing , black or white ( on gray scale )]
##ret,thresh1= cv2.threshold(img,X,Y,cv2.THRESH_BINARY)
## any value under X will be 0 , above Y = 255

ret,thresh1= cv2.threshold(img,127,255,cv2.THRESH_BINARY)
## qualquer valor abaixo de 127=0 ; acima = 255

# %%
plt.imshow(thresh1,cmap='gray')
