# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# nat = cv2.imread('img/nature.jpg')
# show_nat = cv2.cvtColor(nat, cv2.COLOR_BGR2RGB)

parede = cv2.imread('./imgs/flower.jpg')
type(parede)
# show_parede = cv2.cvtColor(parede, cv2.COLOR_BGR2RGB)

# rainbow = cv2.imread('img/rainbow.jpg')
# show_rainbow = cv2.cvtColor(rainbow, cv2.COLOR_BGR2RGB)
# Out:
# NoneType

# %%
plt.imshow(show_parede)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-e2cc5b39acf3> in <module>
# ----> 1 plt.imshow(show_parede)
#
# NameError: name 'show_parede' is not defined

# %%
#OPENCV = BGR
hist = cv2.calcHist([parede],channels=[2],mask=None,histSize=[256],ranges=[0,256])

# %%
hist.shape
# Out:
# (256, 1)

# %%
plt.plot(hist)

# %%
img = parede

# %%
cores = ('b','g','r')

for i, col in enumerate(cores):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color=col)
    plt.xlim([0,256])
    plt.ylim([0,15000])
    
plt.title('Histograma')
# Out:
# Text(0.5, 1.0, 'Histograma')
